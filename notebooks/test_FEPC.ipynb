# %%
import sys
sys.path.append("..")

from src.ambiente import Hexapawn

# %%
env = Hexapawn()
env.display()

moves = env.get_legal_moves()
print("Movimientos legales:", moves)

env.make_move(moves[0])
env.display()

print("Ganador:", env.check_winner())
# Out:
# Turno de: Blancas
# B B B
# . . .
# W W W
#
# Movimientos legales: [((2, 0), (1, 0)), ((2, 1), (1, 1)), ((2, 2), (1, 2))]
#
# Turno de: Negras
# B B B
# W . .
# . W W
#
# Ganador: None
