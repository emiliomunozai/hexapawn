# %% [markdown]
# ## Hexpawn
# ### Juan E Gonzalez

# %%
import sys
import os
sys.path.append(os.path.abspath(".."))
from src.ambiente import Hexpawn

# %% [markdown]
# test

# %%
game = Hexpawn()

while not game.check_winner():
    game.display()
    moves = game.get_legal_moves(game.turn)
    
    if not moves: break
    
    # Aquí podrías pedir input() o dejar que una IA elija
    print(f"Movimientos posibles: {moves}")
    game.make_move(moves[0]) # Elige el primero por defecto

print(f"¡El ganador es: {game.check_winner()}!")
# Out:
# Turno de: Blancas
# B B B
# . . .
# W W W
#
# Movimientos posibles: [((2, 0), (1, 0)), ((2, 1), (1, 1)), ((2, 2), (1, 2))]
#
# Turno de: Negras
# B B B
# W . .
# . W W
#
# Movimientos posibles: [((0, 1), (1, 1)), ((0, 1), (1, 0)), ((0, 2), (1, 2))]
#
# Turno de: Blancas
# B . B
# W B .
# . W W
#
# Movimientos posibles: [((2, 2), (1, 2)), ((2, 2), (1, 1))]
# ¡El ganador es: W!
